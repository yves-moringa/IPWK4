# %% [markdown]
# <a href="https://colab.research.google.com/github/yves-moringa/IPWK4/blob/main/Data_Science_Prep_W4_Independent_Project_2022_04_Yves_Havugimana_Python_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading pandas and numpy packages to our python collab

import pandas as pd

import numpy as np

# %%
# Loading data to our collab using pandas .read_csv

data = pd.read_csv('http://bit.ly/autolib_dataset')

# %%
# Previewing the data

data.head()
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue Eug̬ne Oudin̩     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
#
# [5 rows x 25 columns]

# %%
# previewing dataset

data.describe
# Out:
# <bound method NDFrame.describe of                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]>

# %%
# A look at the columns

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
# Dropping columns 'Displayed comment' and 'Scheduled at' due to missing values

data.drop(['Displayed comment','Scheduled at'], axis = 1, inplace = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   ID                   5000 non-null   object
#  9   Kind                 5000 non-null   object
#  10  Geo point            5000 non-null   object
#  11  Postal code          5000 non-null   int64
#  12  Public name          5000 non-null   object
#  13  Rental status        5000 non-null   object
#  14  Slots                5000 non-null   int64
# ...

# %%
# From documentation, Dalberg identifies the column 'Cars' as identical to column 'Bluecar counter'.
# We drop the column 'Car'.

data.drop('Cars', axis = 1, inplace = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Bluecar counter      5000 non-null   int64
#  2   Utilib counter       5000 non-null   int64
#  3   Utilib 1.4 counter   5000 non-null   int64
#  4   Charge Slots         5000 non-null   int64
#  5   Charging Status      5000 non-null   object
#  6   City                 5000 non-null   object
#  7   ID                   5000 non-null   object
#  8   Kind                 5000 non-null   object
#  9   Geo point            5000 non-null   object
#  10  Postal code          5000 non-null   int64
#  11  Public name          5000 non-null   object
#  12  Rental status        5000 non-null   object
#  13  Slots                5000 non-null   int64
#  14  Station type         5000 non-null   object
# ...

# %%
# Previewing our dataset after removing unecessary columns

data.head()
# Out:
#                               Address  Bluecar counter  ...  hour  minute
# 0                 2 Avenue de Suffren                0  ...    11      43
# 1           145 Rue Raymond Losserand                6  ...     7      24
# 2    2 Avenue John Fitzgerald Kennedy                3  ...    20      14
# 3              51 Rue Eug̬ne Oudin̩                3  ...     4      37
# 4  6 avenue de la Porte de Champerret                3  ...    17      23
#
# [5 rows x 22 columns]

# %%
# Finding duplicate rows

data.duplicated().sum()
# Out:
# 0

# %%
# Unique values in numeric columns

data[data['City']=="Paris"].value_counts(['Bluecar counter', 'hour'])
# Out:
# Bluecar counter  hour
# 0                2       54
#                  3       52
#                  21      52
#                  16      50
#                  8       49
#                          ..
# 6                23       2
#                  16       1
#                  5        1
# 7                3        1
#                  17       1
# Length: 170, dtype: int64

# %%
# Description of numeric data

data.describe()
# Out:
#        Bluecar counter  Utilib counter  ...         hour       minute
# count      5000.000000     5000.000000  ...  5000.000000  5000.000000
# mean          2.333600        0.059600  ...    11.509200    29.270000
# std           2.035274        0.246698  ...     6.893549    17.231741
# min           0.000000        0.000000  ...     0.000000     0.000000
# 25%           0.000000        0.000000  ...     6.000000    14.000000
# 50%           2.000000        0.000000  ...    11.000000    29.000000
# 75%           4.000000        0.000000  ...    18.000000    44.000000
# max           7.000000        2.000000  ...    23.000000    59.000000
#
# [8 rows x 11 columns]

# %%
# Unique value counts

data["Bluecar counter"].value_counts()
# Out:
# 0    1447
# 3     672
# 1     663
# 4     636
# 2     628
# 5     574
# 6     341
# 7      39
# Name: Bluecar counter, dtype: int64

# %%
data["Utilib counter"].value_counts()
# Out:
# 0    4714
# 1     274
# 2      12
# Name: Utilib counter, dtype: int64

# %%
data["Utilib 1.4 counter"].value_counts()
# Out:
# 0    4431
# 1     525
# 2      42
# 3       2
# Name: Utilib 1.4 counter, dtype: int64

# %%
# According to the documentation provided, stations can only be operational if slots are greater than zero.

data[["Charge Slots","Charging Status"]].value_counts()

# Data shows 1001 operational stations with 0 charge slots (error or?)
# Out:
# Charge Slots  Charging Status
# 0             nonexistent        2886
#               operational        1001
# 1             operational         721
# 2             operational         273
# 0             broken              119
# dtype: int64

# %%
# Paris station time with most available cars

paris_data = data[data['City'] == "Paris"]

paris_data
# Out:
#                                  Address  Bluecar counter  ...  hour  minute
# 0                    2 Avenue de Suffren                0  ...    11      43
# 1              145 Rue Raymond Losserand                6  ...     7      24
# 3                 51 Rue Eug̬ne Oudin̩                3  ...     4      37
# 4     6 avenue de la Porte de Champerret                3  ...    17      23
# 5                   8 Boulevard Voltaire                0  ...     7       2
# ...                                  ...              ...  ...   ...     ...
# 4992                     3 avenue d'Ivry                0  ...    23       1
# 4994                    15 rue de Rocroy                0  ...    20      49
# 4996                   37 rue de Dantzig                4  ...    16      56
# 4997                      142 rue du Bac                1  ...     7       1
# 4999                 5 Rue Henry Brisson                4  ...    10       2
#
# [2816 rows x 22 columns]
